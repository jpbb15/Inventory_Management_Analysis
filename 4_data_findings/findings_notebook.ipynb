# %% [markdown]
# # Data Findings

# %%
import pandas as pd
from findings_functions import load_data, plot_monthly_sales_trend, plot_quantity_distribution, plot_customer_purchase_frequency

# %%
file_path = 'C:\\Users\\USER\\Documents\\GitHub\\project_final\\3_data_manipulation\\data_manipulated.csv'
data = load_data(file_path)

# %%
data
# Out:
#                invoicedate  customerid  quantity  unitprice  total_purchase  \
# 0      2010-12-01 08:26:00       17850       6.0       2.55           15.30
# 1      2010-12-01 08:26:00       17850       6.0       3.39           20.34
# 2      2010-12-01 08:26:00       17850       8.0       2.75           22.00
# 3      2010-12-01 08:26:00       17850       6.0       3.39           20.34
# 4      2010-12-01 08:26:00       17850       6.0       3.39           20.34
# ...                    ...         ...       ...        ...             ...
# 541904 2011-12-09 12:50:00       12680      12.0       0.85           10.20
# 541905 2011-12-09 12:50:00       12680       6.0       2.10           12.60
# 541906 2011-12-09 12:50:00       12680       4.0       4.15           16.60
# 541907 2011-12-09 12:50:00       12680       4.0       4.15           16.60
# 541908 2011-12-09 12:50:00       12680       3.0       4.95           14.85
#
#                country month_year
# ...

# %% [markdown]
# ## Statistical Summary

# %%
statistical_summary = data.describe(include='all')
print(statistical_summary)
# Out:
#                           invoicedate     customerid       quantity  \
# count                          541909  541909.000000  541909.000000
# unique                            NaN            NaN            NaN
# top                               NaN            NaN            NaN
# freq                              NaN            NaN            NaN
# mean    2011-07-04 13:34:57.156386048   11476.725404       9.552250
# min               2010-12-01 08:26:00      -1.000000  -80995.000000
# 25%               2011-03-28 11:34:00   12352.000000       1.000000
# 50%               2011-07-19 17:17:00   14382.000000       3.000000
# 75%               2011-10-19 11:27:00   16255.000000      10.000000
# max               2011-12-09 12:50:00   18287.000000   80995.000000
# std                               NaN    6778.330409     218.081158
#
#             unitprice  total_purchase         country month_year
# count   541909.000000   541909.000000          541909     541909
# ...

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Monthly Sales Trends

# %%
plot_monthly_sales_trend(data)

# %% [markdown]
# **Key Insights**:
#
# - **Seasonality**: The trend suggests strong seasonality, with significant peaks during key shopping periods like the holiday season.
#
# - **Promotions and Sales Events**: The sharp rise before November could be linked to promotions or events that significantly boost sales.
#
# - **Inventory Planning**: The decline after November indicates that inventory levels should be carefully managed during these peak times to avoid overstocking after the sales peak.

# %% [markdown]
# ### Customer Purchase Frequency

# %%
plot_customer_purchase_frequency(data)

# %% [markdown]
# **Key Insights**:
#
# - **Customer Retention**: The skewness suggests that retaining customers and encouraging repeat purchases could be a key area of focus. Implementing loyalty programs or targeted marketing campaigns could help increase the purchase frequency among the broader customer base.
#
# - **High-Value Customers**: The long tail indicates that there are some customers with exceptionally high purchase frequency. These customers are likely very valuable and should be nurtured through personalized offers or premium services.
#
# - **Inventory Implications**: Given that a few customers are driving many purchases, inventory management strategies might need to be tailored to cater to these high-frequency buyers, ensuring that popular products for these customers are always in stock.

# %% [markdown]
# ### Distribution of Purchase Quantities

# %%
plot_quantity_distribution(data)

# %% [markdown]
# **Key Insights**:
#
# - **Data Quality Concerns**: The large spike around zero and the presence of extreme negative and positive values could indicate data quality issues, such as incorrect entries or inconsistencies in how transactions are recorded.
#
# - **Return Handling**: The significant negative quantities suggest that returns or cancellations are substantial and might need to be investigated further to understand why they're happening in such large amounts.
#
# - **Inventory Implications**: If the negative quantities are due to returns, this could impact inventory levels and should be factored into inventory management strategies.
